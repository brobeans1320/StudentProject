-- %% [markdown]
-- # [brobeans-students]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [brobeans-students]    Script Date: 6/7/2024 10:04:48 PM ******/
CREATE DATABASE [brobeans-students]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'brobeans-students', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.BROBEANS\MSSQL\DATA\brobeans-students.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'brobeans-students_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.BROBEANS\MSSQL\DATA\brobeans-students_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [brobeans-students] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [brobeans-students].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [brobeans-students] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [brobeans-students] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [brobeans-students] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [brobeans-students] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [brobeans-students] SET ARITHABORT OFF 
GO
ALTER DATABASE [brobeans-students] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [brobeans-students] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [brobeans-students] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [brobeans-students] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [brobeans-students] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [brobeans-students] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [brobeans-students] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [brobeans-students] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [brobeans-students] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [brobeans-students] SET  DISABLE_BROKER 
GO
ALTER DATABASE [brobeans-students] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [brobeans-students] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [brobeans-students] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [brobeans-students] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [brobeans-students] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [brobeans-students] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [brobeans-students] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [brobeans-students] SET RECOVERY FULL 
GO
ALTER DATABASE [brobeans-students] SET  MULTI_USER 
GO
ALTER DATABASE [brobeans-students] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [brobeans-students] SET DB_CHAINING OFF 
GO
ALTER DATABASE [brobeans-students] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [brobeans-students] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [brobeans-students] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [brobeans-students] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'brobeans-students', N'ON'
GO
ALTER DATABASE [brobeans-students] SET QUERY_STORE = ON
GO
ALTER DATABASE [brobeans-students] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Students]

-- %%
USE [brobeans-students]
GO

-- %%
/****** Object:  Table [dbo].[Students]    Script Date: 6/7/2024 10:04:48 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Students](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [varchar](25) NOT NULL,
	[LastName] [varchar](25) NOT NULL,
	[DateOfBirth] [date] NOT NULL,
	[Age] [int] NOT NULL,
	[Major] [varchar](30) NOT NULL,
	[Gpa] [float] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[createStudent]

-- %%
/****** Object:  StoredProcedure [dbo].[createStudent]    Script Date: 6/7/2024 10:04:48 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[createStudent]
    @firstName VARCHAR(25),
    @lastName VARCHAR(25),
    @dateOfBirth DATE,
    @age INT,
    @major VARCHAR(30),
    @gpa FLOAT
AS
BEGIN
    INSERT INTO students (firstName, lastName, dateOfBirth, age, major, gpa)
    VALUES (@firstName, @lastName, @dateOfBirth, @age, @major, @gpa);
END;
GO

-- %% [markdown]
-- # [dbo].[deleteStudent]

-- %%
/****** Object:  StoredProcedure [dbo].[deleteStudent]    Script Date: 6/7/2024 10:04:48 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[deleteStudent]
    @id INT
AS
BEGIN
    DELETE FROM students
    WHERE id = @id;
END;
GO

-- %% [markdown]
-- # [dbo].[selectAllStudents]

-- %%
/****** Object:  StoredProcedure [dbo].[selectAllStudents]    Script Date: 6/7/2024 10:04:48 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[selectAllStudents]
AS
BEGIN
    SELECT 
        id,
        firstName,
        lastName,
        dateOfBirth,
        age,
        major,
        gpa
    FROM students;
END;
GO

-- %% [markdown]
-- # [dbo].[updateStudent]

-- %%
/****** Object:  StoredProcedure [dbo].[updateStudent]    Script Date: 6/7/2024 10:04:48 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[updateStudent]
    @id INT,
    @firstName VARCHAR(25),
    @lastName VARCHAR(25),
    @dateOfBirth DATE,
    @age INT,
    @major VARCHAR(30),
    @gpa FLOAT
AS
BEGIN
    UPDATE students
    SET
        firstName = @firstName,
        lastName = @lastName,
        dateOfBirth = @dateOfBirth,
        age = @age,
        major = @major,
        gpa = @gpa
    WHERE id = @id;
END;
GO

-- %% [markdown]
-- # [brobeans-students]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [brobeans-students] SET  READ_WRITE 
GO
